# %%
from modules.text import *

# %%
img = Image.open('sample_data/image_2.png').convert("RGB")
plt.imshow(img)

# %%
text_results = text_helper('sample_data/image_2.png', True)
# Out:
# ...
# Progress: |--------------------------------------------------| 1.6% Complete
# Progress: |███-----------------------------------------------| 6.4% Complete
# Progress: |█████---------------------------------------------| 10.6% Complete
# Progress: |██████--------------------------------------------| 13.8% Complete
# Progress: |████████------------------------------------------| 16.0% Complete
# Progress: |████████------------------------------------------| 17.8% Complete
# Progress: |█████████-----------------------------------------| 19.0% Complete
# Progress: |██████████----------------------------------------| 21.4% Complete
# Progress: |███████████---------------------------------------| 24.0% Complete
# Progress: |█████████████-------------------------------------| 26.8% Complete
# Progress: |██████████████------------------------------------| 29.7% Complete
# Progress: |████████████████----------------------------------| 32.8% Complete
# ...

# %%
print("coords: " + text_results[0])
print("original text: " + text_results[1])
print("original text: " + text_results[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print("coords: " + text_results[0])
#       2 print("original text: " + text_results[1])
#       3 print("original text: " + text_results[2])
#
# TypeError: can only concatenate str (not "list") to str
